# %% [markdown]
# # RRC DL DL-DCCH RadioBearerConfig DL-DCCH RadioBearerConfig
# 11:16:51.233 04-Aug-20 RRC DL  DL-DCCH RadioBearerConfig DL-DCCH RadioBearerConfig DL-DCCH RRCConnectionReconfiguration
# Message Name: "RRCConnectionReconfiguration", 	Channel Name: "DCCH", 	EARFCN:  275, 	PCI:  151
# LTE_Uu_RRC: DL_DCCH_Message
# -   .   .message:- c1:- rrcConnectionReconfiguration
# -   .   .   .   .   .rrc-TransactionIdentifier: 1
# -   .   .   .   .   .criticalExtensions:- c1:- rrcConnectionReconfiguration-r8
# -   .   .   .   .   .   .   .   .measConfig
# -   .   .   .   .   .   .   .   .   .measIdToRemoveList [ 0 ]: 17
# -   .   .   .   .   .   .   .   .   .measGapConfig:- release: null
# -   .   .   .   .   .   .   .   .radioResourceConfigDedicated
# -   .   .   .   .   .   .   .   .   .drb-ToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .eps-BearerIdentity: 5
# -   .   .   .   .   .   .   .   .   .   .drb-Identity: 4
# -   .   .   .   .   .   .   .   .   .   .rlc-Config:- am
# -   .   .   .   .   .   .   .   .   .   .   .   .ul-AM-RLC
# -   .   .   .   .   .   .   .   .   .   .   .   .   .t-PollRetransmit: 18 ( ms95)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .pollPDU: 4 ( p64)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .pollByte: 8 ( kB750)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .maxRetxThreshold: 6 ( t16)
# -   .   .   .   .   .   .   .   .   .   .   .   .dl-AM-RLC
# -   .   .   .   .   .   .   .   .   .   .   .   .   .t-Reordering: 5 ( ms25)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .t-StatusProhibit: 5 ( ms25)
# -   .   .   .   .   .   .   .   .   .   .logicalChannelIdentity: 5
# -   .   .   .   .   .   .   .   .   .   .logicalChannelConfig
# -   .   .   .   .   .   .   .   .   .   .   .ul-SpecificParameters
# -   .   .   .   .   .   .   .   .   .   .   .   .priority: 11
# -   .   .   .   .   .   .   .   .   .   .   .   .prioritisedBitRate: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .bucketSizeDuration: 3
# -   .   .   .   .   .   .   .   .   .   .   .   .logicalChannelGroup: 3
# -   .   .   .   .   .   .   .   .   .   .rlc-Config-v1510
# -   .   .   .   .   .   .   .   .   .   .   .reestablishRLC-r15: 0
# -   .   .   .   .   .   .   .   .   .drb-ToAddModList [ 1 ]
# -   .   .   .   .   .   .   .   .   .   .eps-BearerIdentity: 6
# -   .   .   .   .   .   .   .   .   .   .drb-Identity: 5
# -   .   .   .   .   .   .   .   .   .   .rlc-Config:- am
# -   .   .   .   .   .   .   .   .   .   .   .   .ul-AM-RLC
# -   .   .   .   .   .   .   .   .   .   .   .   .   .t-PollRetransmit: 18 ( ms95)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .pollPDU: 4 ( p64)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .pollByte: 8 ( kB750)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .maxRetxThreshold: 6 ( t16)
# -   .   .   .   .   .   .   .   .   .   .   .   .dl-AM-RLC
# -   .   .   .   .   .   .   .   .   .   .   .   .   .t-Reordering: 5 ( ms25)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .t-StatusProhibit: 5 ( ms25)
# -   .   .   .   .   .   .   .   .   .   .logicalChannelIdentity: 6
# -   .   .   .   .   .   .   .   .   .   .logicalChannelConfig
# -   .   .   .   .   .   .   .   .   .   .   .ul-SpecificParameters
# -   .   .   .   .   .   .   .   .   .   .   .   .priority: 11
# -   .   .   .   .   .   .   .   .   .   .   .   .prioritisedBitRate: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .bucketSizeDuration: 3
# -   .   .   .   .   .   .   .   .   .   .   .   .logicalChannelGroup: 3
# -   .   .   .   .   .   .   .   .   .   .rlc-Config-v1510
# -   .   .   .   .   .   .   .   .   .   .   .reestablishRLC-r15: 0
# -   .   .   .   .   .   .   .   .   .mac-MainConfig:- explicitValue
# -   .   .   .   .   .   .   .   .   .   .   .drx-Config:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .onDurationTimer: 7 ( psf10)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .drx-InactivityTimer: 14 ( psf100)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .drx-RetransmissionTimer: 4 ( psf8)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .longDRX-CycleStartOffset:- sf320: 269
# -   .   .   .   .   .   .   .   .   .   .   .   .   .shortDRX
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .shortDRX-Cycle: 9 ( sf80)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .drxShortCycleTimer: 2
# -   .   .   .   .   .   .   .   .   .   .   .timeAlignmentTimerDedicated: 6 ( sf10240)
# -   .   .   .   .   .   .   .   .   .   .   .dualConnectivityPHR:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .phr-ModeOtherCG-r12: 1
# -   .   .   .   .   .   .   .   .   .physicalConfigDedicated
# -   .   .   .   .   .   .   .   .   .   .cqi-ReportConfig-r10
# -   .   .   .   .   .   .   .   .   .   .   .cqi-ReportAperiodic-r10:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .cqi-ReportModeAperiodic-r10: 4 ( rm31)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .aperiodicCSI-Trigger-r10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .trigger1-r10: 64
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .trigger2-r10: 32
# -   .   .   .   .   .   .   .   .   .   .   .nomPDSCH-RS-EPRE-Offset: 0
# -   .   .   .   .   .   .   .   .   .   .   .cqi-ReportPeriodic-r10:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .cqi-PUCCH-ResourceIndex-r10: 30
# -   .   .   .   .   .   .   .   .   .   .   .   .   .cqi-pmi-ConfigIndex: 107
# -   .   .   .   .   .   .   .   .   .   .   .   .   .cqi-FormatIndicatorPeriodic-r10:- widebandCQI-r10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .ri-ConfigIndex: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .simultaneousAckNackAndCQI: 1
# -   .   .   .   .   .   .   .   .nonCriticalExtension
# -   .   .   .   .   .   .   .   .   .lateNonCriticalExtension
# -   .   .   .   .   .   .   .   .   .   .nonCriticalExtension
# -   .   .   .   .   .   .   .   .   .   .   .antennaInfoDedicatedPCell-v10i0
# -   .   .   .   .   .   .   .   .   .nonCriticalExtension
# -   .   .   .   .   .   .   .   .   .   .nonCriticalExtension
# -   .   .   .   .   .   .   .   .   .   .   .sCellToAddModList-r10 [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .sCellIndex-r10: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .radioResourceConfigDedicatedSCell-r10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .physicalConfigDedicatedSCell-r10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .ul-Configuration-r10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cqi-ReportConfigSCell-r10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cqi-ReportModeAperiodic-r10: 4 ( rm31)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nomPDSCH-RS-EPRE-Offset-r10: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cqi-ReportPeriodicSCell-r10:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cqi-PUCCH-ResourceIndex-r10: 30
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cqi-pmi-ConfigIndex: 227
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cqi-FormatIndicatorPeriodic-r10:- widebandCQI-r10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ri-ConfigIndex: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .simultaneousAckNackAndCQI: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .antennaInfoDedicatedSCell-v10i0
# -   .   .   .   .   .   .   .   .   .   .   .sCellToAddModList-r10 [ 1 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .sCellIndex-r10: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .radioResourceConfigDedicatedSCell-r10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .physicalConfigDedicatedSCell-r10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .ul-Configuration-r10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cqi-ReportConfigSCell-r10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cqi-ReportModeAperiodic-r10: 4 ( rm31)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nomPDSCH-RS-EPRE-Offset-r10: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cqi-ReportPeriodicSCell-r10:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cqi-PUCCH-ResourceIndex-r10: 30
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cqi-pmi-ConfigIndex: 307
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cqi-FormatIndicatorPeriodic-r10:- widebandCQI-r10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ri-ConfigIndex: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .simultaneousAckNackAndCQI: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .antennaInfoDedicatedSCell-v10i0
# -   .   .   .   .   .   .   .   .   .   .   .nonCriticalExtension
# -   .   .   .   .   .   .   .   .   .   .   .   .nonCriticalExtension
# -   .   .   .   .   .   .   .   .   .   .   .   .   .nonCriticalExtension
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .nonCriticalExtension
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nonCriticalExtension
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nr-Config-r15:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .endc-ReleaseAndAdd-r15: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nr-SecondaryCellGroupConfig-r15: ...
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .---EMBEDDED CONTAINER DECODING START---
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .NR_Uu_RRC:
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .RRCReconfiguration
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .rrc-TransactionIdentifier: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .criticalExtensions:- rrcReconfiguration
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .secondaryCellGroup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cellGroupId: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .rlc-BearerToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .logicalChannelIdentity: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .servedRadioBearer:- drb-Identity: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reestablishRLC: 0 ( true)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .rlc-Config:- am
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ul-AM-RLC
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .sn-FieldLength: 1 ( size18)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .t-PollRetransmit: 8 ( ms45)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pollPDU: 4 ( p64)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pollByte: 13 ( kB500)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .maxRetxThreshold: 7 ( t32)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dl-AM-RLC
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .sn-FieldLength: 1 ( size18)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .t-Reassembly: 3 ( ms15)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .t-StatusProhibit: 3 ( ms15)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mac-LogicalChannelConfig
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ul-SpecificParameters
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .priority: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .prioritisedBitRate: 15 ( infinity)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bucketSizeDuration: 3 ( ms50)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .logicalChannelGroup: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .schedulingRequestID: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .logicalChannelSR-Mask: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .logicalChannelSR-DelayTimerApplied: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .rlc-BearerToAddModList [ 1 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .logicalChannelIdentity: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .servedRadioBearer:- drb-Identity: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reestablishRLC: 0 ( true)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .rlc-Config:- am
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ul-AM-RLC
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .sn-FieldLength: 1 ( size18)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .t-PollRetransmit: 8 ( ms45)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pollPDU: 4 ( p64)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pollByte: 13 ( kB500)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .maxRetxThreshold: 7 ( t32)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dl-AM-RLC
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .sn-FieldLength: 1 ( size18)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .t-Reassembly: 3 ( ms15)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .t-StatusProhibit: 3 ( ms15)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mac-LogicalChannelConfig
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ul-SpecificParameters
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .priority: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .prioritisedBitRate: 15 ( infinity)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bucketSizeDuration: 3 ( ms50)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .logicalChannelGroup: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .schedulingRequestID: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .logicalChannelSR-Mask: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .logicalChannelSR-DelayTimerApplied: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mac-CellGroupConfig
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .schedulingRequestConfig
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .schedulingRequestToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .schedulingRequestId: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .sr-TransMax: 4 ( n64)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bsr-Config
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicBSR-Timer: 2 ( sf10)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .retxBSR-Timer: 5 ( sf320)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tag-Config
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tag-ToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tag-Id: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .timeAlignmentTimer: 7 ( infinity)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .phr-Config:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .phr-PeriodicTimer: 1 ( sf20)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .phr-ProhibitTimer: 0 ( sf0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .phr-Tx-PowerFactorChange: 1 ( dB3)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .multiplePHR: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dummy: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .phr-Type2OtherCell: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .phr-ModeOtherCG: 0 ( real)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .skipUplinkTxDynamic: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .physicalCellGroupConfig
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .p-NR-FR1: 23
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-HARQ-ACK-Codebook: 1 ( dynamic)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .spCellConfig
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .servCellIndex: 8
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reconfigurationWithSync
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .spCellConfigCommon
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .physCellId: 151 (151)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .downlinkConfigCommon
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyInfoDL
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .absoluteFrequencySSB: 636000
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyBandList [ 0 ]: 78
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .absoluteFrequencyPointA: 634056
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scs-SpecificCarrierList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .offsetToCarrier: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .subcarrierSpacing: 1 ( kHz30)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .carrierBandwidth: 162
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .initialDownlinkBWP
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .genericParameters
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .locationAndBandwidth: 12980
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .subcarrierSpacing: 1 ( kHz30)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdcch-ConfigCommon:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .controlResourceSetZero: 12
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .searchSpaceZero: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-ConfigCommon:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 40
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 1 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 54
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 2 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 53
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 3 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 67
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 4 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 66
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 5 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 80
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 6 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 96
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 7 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 100
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 8 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 87
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 9 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 99
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 10 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 86
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 11 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 73
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .uplinkConfigCommon
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyInfoUL
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scs-SpecificCarrierList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .offsetToCarrier: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .subcarrierSpacing: 1 ( kHz30)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .carrierBandwidth: 162
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .p-Max: 23
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .initialUplinkBWP
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .genericParameters
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .locationAndBandwidth: 12980
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .subcarrierSpacing: 1 ( kHz30)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .rach-ConfigCommon:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .rach-ConfigGeneric
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .prach-ConfigurationIndex: 98
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .msg1-FDM: 0 ( one)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .msg1-FrequencyStart: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .zeroCorrelationZoneConfig: 13
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .preambleReceivedTargetPower: -104
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .preambleTransMax: 6 ( n10)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerRampingStep: 1 ( dB2)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ra-ResponseWindow: 5 ( sl20)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ssb-perRACH-OccasionAndCB-PreamblesPerSSB:- one: 9 ( n40)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ra-ContentionResolutionTimer: 7 ( sf64)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .rsrp-ThresholdSSB: 37 (-120.00 dBm)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .prach-RootSequenceIndex:- l139: 80
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .msg1-SubcarrierSpacing: 1 ( kHz30)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .restrictedSetConfig: 0 ( unrestrictedSet)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pusch-ConfigCommon:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pusch-TimeDomainAllocationList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .k2: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 1 ( typeB)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 55
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pusch-TimeDomainAllocationList [ 1 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .k2: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 1 ( typeB)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 69
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pusch-TimeDomainAllocationList [ 2 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .k2: 3
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 1 ( typeB)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 55
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pusch-TimeDomainAllocationList [ 3 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .k2: 3
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 1 ( typeB)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 69
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pusch-TimeDomainAllocationList [ 4 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .k2: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 1 ( typeB)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 55
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pusch-TimeDomainAllocationList [ 5 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .k2: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 1 ( typeB)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 69
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pusch-TimeDomainAllocationList [ 6 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .k2: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 1 ( typeB)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 55
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pusch-TimeDomainAllocationList [ 7 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .k2: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 1 ( typeB)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 69
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .msg3-DeltaPreamble: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .p0-NominalWithGrant: -96
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pucch-ConfigCommon:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pucch-GroupHopping: 0 ( neither)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .hoppingId: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .p0-nominal: -100
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dummy: 0 ( ms500)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ssb-PositionsInBurst:- mediumBitmap: 252
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ssb-periodicityServingCell: 2 ( ms20)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dmrs-TypeA-Position: 1 ( pos3)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ssbSubcarrierSpacing: 1 ( kHz30)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tdd-UL-DL-ConfigurationCommon
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .referenceSubcarrierSpacing: 1 ( kHz30)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pattern1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dl-UL-TransmissionPeriodicity: 5 ( ms2p5)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofDownlinkSlots: 3
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofDownlinkSymbols: 10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofUplinkSlots: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofUplinkSymbols: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pattern2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dl-UL-TransmissionPeriodicity: 5 ( ms2p5)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofDownlinkSlots: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofDownlinkSymbols: 10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofUplinkSlots: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofUplinkSymbols: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ss-PBCH-BlockPower: 22
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .newUE-Identity: 9515
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .t304: 6 ( ms2000)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .rlf-TimersAndConstants:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .t310: 6 ( ms2000)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .n310: 6 ( n10)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .n311: 0 ( n1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .t311: 6 ( ms30000)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .spCellConfigDedicated
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .downlinkBWP-ToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Common
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .genericParameters
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .locationAndBandwidth: 31624
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .subcarrierSpacing: 1 ( kHz30)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdcch-ConfigCommon:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .commonSearchSpaceList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .searchSpaceId: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .controlResourceSetId: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .monitoringSlotPeriodicityAndOffset:- sl1: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .monitoringSymbolsWithinSlot: 12288
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofCandidates
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .aggregationLevel1: 0 ( n0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .aggregationLevel2: 0 ( n0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .aggregationLevel4: 1 ( n1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .aggregationLevel8: 0 ( n0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .aggregationLevel16: 0 ( n0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .searchSpaceType:- commonX
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dci-Format0-0-AndFormat1-0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ra-SearchSpace: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-ConfigCommon:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 40
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 1 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 54
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 2 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 53
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 3 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 67
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 4 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 66
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 5 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 80
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 6 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 96
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 7 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 100
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 8 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 87
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 9 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 99
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 10 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 86
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-TimeDomainAllocationList [ 11 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 73
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Dedicated
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdcch-Config:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .controlResourceSetToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .controlResourceSetId: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainResources: 1111 1111 1111 1111 0000 0000 0000 0000 0000 0000 0000 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .duration: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cce-REG-MappingType:- nonInterleaved: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .precoderGranularity: 0 ( sameAsREG_bundle)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StatesPDCCH-ToAddList [ 0 ]: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StatesPDCCH-ToAddList [ 1 ]: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StatesPDCCH-ToAddList [ 2 ]: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StatesPDCCH-ToAddList [ 3 ]: 3
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StatesPDCCH-ToAddList [ 4 ]: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StatesPDCCH-ToAddList [ 5 ]: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .searchSpacesToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .searchSpaceId: 3
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .controlResourceSetId: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .monitoringSlotPeriodicityAndOffset:- sl1: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .monitoringSymbolsWithinSlot: 12288
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofCandidates
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .aggregationLevel1: 0 ( n0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .aggregationLevel2: 0 ( n0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .aggregationLevel4: 1 ( n1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .aggregationLevel8: 0 ( n0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .aggregationLevel16: 0 ( n0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .searchSpaceType:- commonX
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dci-Format0-0-AndFormat1-0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .searchSpacesToAddModList [ 1 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .searchSpaceId: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .controlResourceSetId: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .monitoringSlotPeriodicityAndOffset:- sl1: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .monitoringSymbolsWithinSlot: 12288
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofCandidates
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .aggregationLevel1: 0 ( n0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .aggregationLevel2: 0 ( n0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .aggregationLevel4: 0 ( n0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .aggregationLevel8: 2 ( n2)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .aggregationLevel16: 0 ( n0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .searchSpaceType:- ue-Specific
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dci-Formats: 1 ( formats0_1_And_1_1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-Config:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dmrs-DownlinkForPDSCH-MappingTypeA:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dmrs-AdditionalPosition: 1 ( pos1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID0: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID1: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StatesToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StateId: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .referenceSignal:- csi-rs: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StatesToAddModList [ 1 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StateId: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .referenceSignal:- csi-rs: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StatesToAddModList [ 2 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StateId: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .referenceSignal:- csi-rs: 10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StatesToAddModList [ 3 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StateId: 3
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .referenceSignal:- csi-rs: 14
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StatesToAddModList [ 4 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StateId: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .referenceSignal:- csi-rs: 18
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StatesToAddModList [ 5 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StateId: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .referenceSignal:- csi-rs: 22
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type: 0 ( typeA)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StatesToAddModList [ 6 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StateId: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .referenceSignal:- ssb: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type: 2 ( typeC)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StatesToAddModList [ 7 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StateId: 7
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .referenceSignal:- ssb: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type: 2 ( typeC)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StatesToAddModList [ 8 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StateId: 8
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .referenceSignal:- ssb: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type: 2 ( typeC)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StatesToAddModList [ 9 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StateId: 9
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .referenceSignal:- ssb: 3
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type: 2 ( typeC)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StatesToAddModList [ 10 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StateId: 10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .referenceSignal:- ssb: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type: 2 ( typeC)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StatesToAddModList [ 11 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tci-StateId: 11
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .referenceSignal:- ssb: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-Type: 2 ( typeC)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceAllocation: 0 ( resourceAllocationType0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .rbg-Size: 0 ( config1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mcs-Table: 0 ( qam256)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .maxNrofCodeWordsScheduledByDCI: 0 ( n1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .prb-BundlingType:- staticBundling
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bundleSize: 1 ( wideband)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceAllocationForDCI-Format1-2-r16
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .radioLinkMonitoringConfig:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .beamFailureInstanceMaxCount: 2 ( n3)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .beamFailureDetectionTimer: 1 ( pbfd2)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstActiveDownlinkBWP-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .uplinkConfig
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .uplinkBWP-ToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Common
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .genericParameters
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .locationAndBandwidth: 31624
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .subcarrierSpacing: 1 ( kHz30)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .rach-ConfigCommon:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .rach-ConfigGeneric
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .prach-ConfigurationIndex: 98
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .msg1-FDM: 0 ( one)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .msg1-FrequencyStart: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .zeroCorrelationZoneConfig: 13
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .preambleReceivedTargetPower: -104
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .preambleTransMax: 6 ( n10)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerRampingStep: 1 ( dB2)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ra-ResponseWindow: 5 ( sl20)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ssb-perRACH-OccasionAndCB-PreamblesPerSSB:- one: 9 ( n40)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ra-ContentionResolutionTimer: 7 ( sf64)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .rsrp-ThresholdSSB: 37 (-120.00 dBm)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .prach-RootSequenceIndex:- l139: 80
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .msg1-SubcarrierSpacing: 1 ( kHz30)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .restrictedSetConfig: 0 ( unrestrictedSet)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pusch-ConfigCommon:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pusch-TimeDomainAllocationList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .k2: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 1 ( typeB)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 55
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pusch-TimeDomainAllocationList [ 1 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .k2: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 1 ( typeB)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 69
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pusch-TimeDomainAllocationList [ 2 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .k2: 3
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 1 ( typeB)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 55
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pusch-TimeDomainAllocationList [ 3 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .k2: 3
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 1 ( typeB)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 69
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pusch-TimeDomainAllocationList [ 4 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .k2: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 1 ( typeB)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 55
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pusch-TimeDomainAllocationList [ 5 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .k2: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 1 ( typeB)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 69
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pusch-TimeDomainAllocationList [ 6 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .k2: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 1 ( typeB)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 55
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pusch-TimeDomainAllocationList [ 7 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .k2: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .mappingType: 1 ( typeB)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startSymbolAndLength: 69
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .msg3-DeltaPreamble: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .p0-NominalWithGrant: -96
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pucch-ConfigCommon:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pucch-GroupHopping: 0 ( neither)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .hoppingId: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .p0-nominal: -100
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Dedicated
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pucch-Config:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceSetToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pucch-ResourceSetId: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceList [ 0 ]: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceList [ 1 ]: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceSetToAddModList [ 1 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pucch-ResourceSetId: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceList [ 0 ]: 3
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceList [ 1 ]: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pucch-ResourceId: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingPRB: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .format:- format0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .initialCyclicShift: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofSymbols: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingSymbolIndex: 13
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceToAddModList [ 1 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pucch-ResourceId: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingPRB: 139
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .format:- format0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .initialCyclicShift: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofSymbols: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingSymbolIndex: 13
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceToAddModList [ 2 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pucch-ResourceId: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingPRB: 139
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .format:- format0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .initialCyclicShift: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofSymbols: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingSymbolIndex: 12
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceToAddModList [ 3 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pucch-ResourceId: 3
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingPRB: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .format:- format2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPRBs: 16
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofSymbols: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingSymbolIndex: 13
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceToAddModList [ 4 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pucch-ResourceId: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingPRB: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .format:- format2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPRBs: 16
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofSymbols: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingSymbolIndex: 12
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceToAddModList [ 5 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pucch-ResourceId: 11
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingPRB: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .format:- format2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPRBs: 8
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofSymbols: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingSymbolIndex: 13
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceToAddModList [ 6 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pucch-ResourceId: 12
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingPRB: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .format:- format2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPRBs: 16
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofSymbols: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingSymbolIndex: 13
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .format2:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .maxCodeRate: 1 ( zeroDot15)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .simultaneousHARQ-ACK-CSI: 0 ( true)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .schedulingRequestResourceToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .schedulingRequestResourceId: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .schedulingRequestID: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- sl160: 107
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resource: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dl-DataToUL-ACK [ 0 ]: 3
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dl-DataToUL-ACK [ 1 ]: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dl-DataToUL-ACK [ 2 ]: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dl-DataToUL-ACK [ 3 ]: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dl-DataToUL-ACK [ 4 ]: 7
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dl-DataToUL-ACK [ 5 ]: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dl-DataToUL-ACK [ 6 ]: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dl-DataToUL-ACK [ 7 ]: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pucch-PowerControl
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .deltaF-PUCCH-f0: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .deltaF-PUCCH-f1: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .deltaF-PUCCH-f2: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .deltaF-PUCCH-f3: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .deltaF-PUCCH-f4: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .p0-Set [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .p0-PUCCH-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .p0-PUCCH-Value: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pusch-Config:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .txConfig: 0 ( codebook)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dmrs-UplinkForPUSCH-MappingTypeB:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .dmrs-AdditionalPosition: 1 ( pos1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .transformPrecodingDisabled
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pusch-PowerControl
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .msg3-Alpha: 7 ( alpha1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .p0-AlphaSets [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .p0-PUSCH-AlphaSetId: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .p0: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .alpha: 7 ( alpha1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceAllocation: 1 ( resourceAllocationType1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .transformPrecoder: 1 ( disabled)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .codebookSubset: 2 ( nonCoherent)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .maxRank: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceAllocationForDCI-Format0-2-r16
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .srs-Config:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .srs-ResourceSetToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .srs-ResourceSetId: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .srs-ResourceIdList [ 0 ]: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceType:- aperiodic
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .aperiodicSRS-ResourceTrigger: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .slotOffset: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .usage: 1 ( codebook)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .alpha: 7 ( alpha1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .p0: -72
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .srs-ResourceToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .srs-ResourceId: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofSRS-Ports: 0 ( port1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .transmissionComb:- n2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .combOffset-n2: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cyclicShift-n2: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startPosition: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofSymbols: 0 ( n1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .repetitionFactor: 0 ( n1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqDomainPosition: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqDomainShift: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqHopping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .c-SRS: 40
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .b-SRS: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .b-hop: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .groupOrSequenceHopping: 0 ( neither)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceType:- aperiodic
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .sequenceId: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .spatialRelationInfo
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .referenceSignal:- csi-RS-Index: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstActiveUplinkBWP-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pusch-ServingCellConfig:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .maxMIMO-Layers: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdsch-ServingCellConfig:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .maxMIMO-Layers: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-MeasConfig:- setup
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row4: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 2 ( p4)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 1 ( fd_CDM2)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- one: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 0 ( db_3)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots320: 280
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 1 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 21
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 2 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 3
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 8
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 21
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 3 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 22
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 4 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 8
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 22
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 5 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 21
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 7
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 6 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 7
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 8
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 21
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 7
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 7 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 8
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 22
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 7
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 8 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 9
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 8
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 22
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 7
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 9 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 21
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 8
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 10 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 11
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 9
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 21
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 8
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 11 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 12
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 22
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 8
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 12 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 13
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 9
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 22
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 8
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 13 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 14
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 8
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 21
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 9
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 14 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 15
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 8
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 9
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 21
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 9
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 15 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 16
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 8
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 22
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 9
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 16 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 17
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 8
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 9
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 22
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 9
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 17 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 18
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 21
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 18 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 19
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 21
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 19 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 20
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 22
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 20 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 21
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 22
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 21 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 22
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 21
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 11
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 22 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 23
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 21
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 11
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 23 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 24
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 22
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 11
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceToAddModList [ 24 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceId: 25
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceMapping
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .frequencyDomainAllocation:- row1: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofPorts: 0 ( p1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .firstOFDMSymbolInTimeDomain: 10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cdm-Type: 0 ( noCDM)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .density:- three: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffset: -4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .powerControlOffsetSS: 1 ( db0)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .scramblingID: 151
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots160: 22
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .qcl-InfoPeriodicCSI-RS: 11
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceSetToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-ResourceSetId: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 0 ]: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceSetToAddModList [ 1 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-ResourceSetId: 3
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 0 ]: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 1 ]: 3
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 2 ]: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 3 ]: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .repetition: 1 ( off)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .trs-Info: 0 ( true)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceSetToAddModList [ 2 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-ResourceSetId: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 0 ]: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 1 ]: 7
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 2 ]: 8
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 3 ]: 9
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .repetition: 1 ( off)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .trs-Info: 0 ( true)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceSetToAddModList [ 3 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-ResourceSetId: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 0 ]: 10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 1 ]: 11
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 2 ]: 12
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 3 ]: 13
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .repetition: 1 ( off)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .trs-Info: 0 ( true)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceSetToAddModList [ 4 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-ResourceSetId: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 0 ]: 14
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 1 ]: 15
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 2 ]: 16
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 3 ]: 17
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .repetition: 1 ( off)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .trs-Info: 0 ( true)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceSetToAddModList [ 5 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-ResourceSetId: 7
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 0 ]: 18
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 1 ]: 19
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 2 ]: 20
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 3 ]: 21
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .repetition: 1 ( off)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .trs-Info: 0 ( true)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceSetToAddModList [ 6 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-ResourceSetId: 8
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 0 ]: 22
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 1 ]: 23
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 2 ]: 24
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-Resources [ 3 ]: 25
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .repetition: 1 ( off)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .trs-Info: 0 ( true)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-IM-ResourceToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-IM-ResourceId: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-IM-ResourceElementPattern:- pattern1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .subcarrierLocation-p1: 1 ( s4)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .symbolLocation-p1: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBand
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .startingRB: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofRBs: 164
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- slots320: 280
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-IM-ResourceSetToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-IM-ResourceSetId: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-IM-Resources [ 0 ]: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-SSB-ResourceSetToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-SSB-ResourceSetId: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-SSB-ResourceList [ 0 ]: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-SSB-ResourceList [ 1 ]: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-SSB-ResourceList [ 2 ]: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-SSB-ResourceList [ 3 ]: 3
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-SSB-ResourceList [ 4 ]: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-SSB-ResourceList [ 5 ]: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-ResourceConfigToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-ResourceConfigId: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-RS-ResourceSetList:- nzp-CSI-RS-SSB
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceSetList [ 0 ]: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceType: 2 ( periodic)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-ResourceConfigToAddModList [ 1 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-ResourceConfigId: 11
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-RS-ResourceSetList:- csi-IM-ResourceSetList
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-IM-ResourceSetList [ 0 ]: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceType: 2 ( periodic)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-ResourceConfigToAddModList [ 2 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-ResourceConfigId: 10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-RS-ResourceSetList:- nzp-CSI-RS-SSB
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-SSB-ResourceSetList [ 0 ]: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceType: 2 ( periodic)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-ResourceConfigToAddModList [ 3 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-ResourceConfigId: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-RS-ResourceSetList:- nzp-CSI-RS-SSB
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceSetList [ 0 ]: 3
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceType: 2 ( periodic)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-ResourceConfigToAddModList [ 4 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-ResourceConfigId: 3
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-RS-ResourceSetList:- nzp-CSI-RS-SSB
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceSetList [ 0 ]: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceType: 2 ( periodic)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-ResourceConfigToAddModList [ 5 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-ResourceConfigId: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-RS-ResourceSetList:- nzp-CSI-RS-SSB
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceSetList [ 0 ]: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceType: 2 ( periodic)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-ResourceConfigToAddModList [ 6 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-ResourceConfigId: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-RS-ResourceSetList:- nzp-CSI-RS-SSB
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceSetList [ 0 ]: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceType: 2 ( periodic)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-ResourceConfigToAddModList [ 7 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-ResourceConfigId: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-RS-ResourceSetList:- nzp-CSI-RS-SSB
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceSetList [ 0 ]: 7
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceType: 2 ( periodic)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-ResourceConfigToAddModList [ 8 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-ResourceConfigId: 7
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-RS-ResourceSetList:- nzp-CSI-RS-SSB
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nzp-CSI-RS-ResourceSetList [ 0 ]: 8
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .bwp-Id: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourceType: 2 ( periodic)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-ReportConfigToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reportConfigId: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourcesForChannelMeasurement: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-IM-ResourcesForInterference: 11
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reportConfigType:- periodic
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reportSlotConfig:- slots320: 267
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pucch-CSI-ResourceList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .uplinkBandwidthPartId: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pucch-Resource: 11
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reportQuantity:- cri-RI-PMI-CQI: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reportFreqConfiguration
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cqi-FormatIndicator: 0 ( widebandCQI)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pmi-FormatIndicator: 0 ( widebandPMI)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-ReportingBand:- subbands11: 2047
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .timeRestrictionForChannelMeasurements: 0 ( configured)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .timeRestrictionForInterferenceMeasurements: 0 ( configured)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .codebookConfig
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .codebookType:- type1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .subType:- typeI-SinglePanel
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrOfAntennaPorts:- moreThanTwo
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .n1-n2:- two-one-TypeI-SinglePanel-Restriction: 255
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .typeI-SinglePanel-ri-Restriction: 15
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .codebookMode: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .groupBasedBeamReporting:- disabled
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cqi-Table: 1 ( table2)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .subbandSize: 0 ( value1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-ReportConfigToAddModList [ 1 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reportConfigId: 2
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .resourcesForChannelMeasurement: 10
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reportConfigType:- periodic
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reportSlotConfig:- slots320: 268
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pucch-CSI-ResourceList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .uplinkBandwidthPartId: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pucch-Resource: 12
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reportQuantity:- ssb-Index-RSRP: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reportFreqConfiguration
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cqi-FormatIndicator: 0 ( widebandCQI)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pmi-FormatIndicator: 0 ( widebandPMI)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .timeRestrictionForChannelMeasurements: 0 ( configured)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .timeRestrictionForInterferenceMeasurements: 0 ( configured)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .codebookConfig
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .codebookType:- type1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .subType:- typeI-SinglePanel
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrOfAntennaPorts:- moreThanTwo
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .n1-n2:- two-one-TypeI-SinglePanel-Restriction: 255
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .typeI-SinglePanel-ri-Restriction: 15
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .codebookMode: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .groupBasedBeamReporting:- disabled
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofReportedRS: 1 ( n2)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cqi-Table: 1 ( table2)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .subbandSize: 0 ( value1)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .tag-Id: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .servingCellMO: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .measConfig
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .measObjectToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .measObjectId: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .measObject:- measObjectNR
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ssbFrequency: 636000
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ssbSubcarrierSpacing: 1 ( kHz30)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .smtc1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .periodicityAndOffset:- sf20: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .duration: 4 ( sf5)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .referenceSignalConfig
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ssb-ConfigMobility
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .deriveSSB-IndexFromCell: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .absThreshSS-BlocksConsolidation
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .thresholdRSRP: 36 (-121.00 dBm)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nrofSS-BlocksToAverage: 16
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .quantityConfigIndex: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .offsetMO
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .freqBandIndicatorNR: 78
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reportConfigToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reportConfigId: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reportConfig:- reportConfigNR
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reportType:- eventTriggered
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .eventId:- eventA3
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .a3-Offset:- rsrp: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reportOnLeave: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .hysteresis: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .timeToTrigger: 8 ( ms320)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .useWhiteCellList: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .rsType: 0 ( ssb)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reportInterval: 0 ( ms120)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reportAmount: 2 ( r4)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reportQuantityCell
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .rsrp: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .rsrq: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .sinr: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .maxReportCells: 8
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reportQuantityRS-Indexes
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .rsrp: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .rsrq: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .sinr: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .maxNrofRS-IndexesToReport: 8
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .includeBeamMeasurements: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .measIdToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .measId: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .measObjectId: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reportConfigId: 1
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .s-MeasureConfig:- ssb-RSRP: 91 (-66.00 dBm)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .quantityConfig
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .quantityConfigNR-List [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .quantityConfigCell
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ssb-FilterConfig
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-RS-FilterConfig
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .quantityConfigRS-Index
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .ssb-FilterConfig
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .csi-RS-FilterConfig
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .---EMBEDDED CONTAINER DECODING END---
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .sk-Counter-r15: 0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .nr-RadioBearerConfig2-r15: 0x142d28dfafc52839a623f5f8a50730a0
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .---EMBEDDED CONTAINER DECODING START---
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .NR_Uu_RRC:
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .RadioBearerConfig
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .drb-ToAddModList [ 0 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cnAssociation:- eps-BearerIdentity: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .drb-Identity: 4
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reestablishPDCP: 0 ( true)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdcp-Config
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .drb
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .discardTimer: 15 ( infinity)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdcp-SN-SizeUL: 1 ( len18bits)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdcp-SN-SizeDL: 1 ( len18bits)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .headerCompression:- notUsed: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .statusReportRequired: 0 ( true)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .moreThanOneRLC
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .primaryPath
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .**cellGroup: 1**
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .**ul-DataSplitThreshold: 8 ( b12800)**
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .t-Reordering: 14 ( ms100)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .drb-ToAddModList [ 1 ]
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cnAssociation:- eps-BearerIdentity: 6
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .drb-Identity: 5
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .reestablishPDCP: 0 ( true)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdcp-Config
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .drb
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .discardTimer: 15 ( infinity)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdcp-SN-SizeUL: 1 ( len18bits)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .pdcp-SN-SizeDL: 1 ( len18bits)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .headerCompression:- notUsed: null
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .statusReportRequired: 0 ( true)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .moreThanOneRLC
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .primaryPath
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .**cellGroup: 1**
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .**ul-DataSplitThreshold: 8 ( b12800)**
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .t-Reordering: 14 ( ms100)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .securityConfig
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .securityAlgorithmConfig
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .cipheringAlgorithm: 2 ( nea2)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .keyToUse: 1 ( secondary)
# -   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .   .---EMBEDDED CONTAINER DECODING END---

# %%
#To parse timestamp and the cellGroup information from NR Uu RRC

# %%
import re
import csv

# %%
inputFile = r'c:/Work/studty/ParsePrimaryCellGroup/rawMsg.txt'
outputFile = r'c:/Work/studty/ParsePrimaryCellGroup/out.csv'

# %%
timePattern = r'[\d:\.]+\s[\w-]+-\d+'

# %%
cellGroupPattern = r'cellGroup:\s\d'

# %%
splitPattern = r'ul-DataSplitThreshold:[\s\d(\w]+\)'

# %%
#write to list and then write to csv
with open(inputFile) as file:
    finalList = []
    tempList = []
    for f in file:
        #find timestamp
        if bool(re.search(timePattern, f)):
            #only update finalList if  there are more than one cell group information is found.
            if(len(tempList) > 1):
                finalList.append(tempList)
                tempList = []
                tempList.append(re.search(timePattern, f)[0])
            else:
                tempList=[]
                tempList.append(re.search(timePattern, f)[0])
        #find cell group information
        if bool(re.search(cellGroupPattern, f)):
            tempList.append(re.search(cellGroupPattern, f)[0])
        #find ul split information
        if bool(re.search(splitPattern, f)):
            tempList.append(re.search(splitPattern, f)[0])
finalList
# Out:
# [['11:16:51.233 04-Aug-20',
#   'cellGroup: 1',
#   'ul-DataSplitThreshold: 8 ( b12800)',
#   'cellGroup: 1',
#   'ul-DataSplitThreshold: 8 ( b12800)'],
#  ['11:16:51.233 04-Aug-20',
#   'cellGroup: 1',
#   'ul-DataSplitThreshold: 8 ( b12800)',
#   'cellGroup: 1',
#   'ul-DataSplitThreshold: 8 ( b12800)'],
#  ['11:17:21.145 04-Aug-20',
#   'cellGroup: 0',
#   'ul-DataSplitThreshold: 23 ( infinity)',
#   'cellGroup: 0',
#   'ul-DataSplitThreshold: 23 ( infinity)'],
#  ['11:17:21.145 04-Aug-20',
#   'cellGroup: 0',
#   'ul-DataSplitThreshold: 23 ( infinity)',
#   'cellGroup: 0',
#   'ul-DataSplitThreshold: 23 ( infinity)'],
#  ['11:18:43.796 04-Aug-20',
#   'cellGroup: 0',
#   'ul-DataSplitThreshold: 23 ( infinity)',
#   'cellGroup: 0',
#   'ul-DataSplitThreshold: 23 ( infinity)'],
#  ['11:18:43.796 04-Aug-20',
#   'cellGroup: 0',
#   'ul-DataSplitThreshold: 23 ( infinity)',
#   'cellGroup: 0',
#   'ul-DataSplitThreshold: 23 ( infinity)'],
#  ['11:18:56.900 04-Aug-20',
# ...

# %%
#write finalList to csv
with open(outputFile, 'w', newline='') as outCsv:
    writer = csv.writer(outCsv)
    writer.writerows(finalList)

# %%
import os

# %%
os.path.basename(inputFile)
# Out:
# 'rawMsg.txt'

# %%
os.path.splitext(inputFile)[0]
# Out:
# 'c:/Work/studty/ParsePrimaryCellGroup/rawMsg'
